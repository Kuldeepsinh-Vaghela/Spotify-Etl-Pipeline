# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# !pip install --upgrade spotipy
# Out:
# ...
#   Attempting uninstall: spotipy
#     Found existing installation: spotipy 2.23.0
#     Uninstalling spotipy-2.23.0:
#       Successfully uninstalled spotipy-2.23.0
# ...

# %%
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

# %%
client_id

# %%
client_credentials_manager =  SpotifyClientCredentials(client_id = 'f2a387d1bbd54d6ba7144ba861bb112c',client_secret = 'bff9dc3724f34ef590294ff89d0e16b6')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V"

# %%
artist_id = playlist_link.split('/')[-1]

# %%
print(artist_id)
# Out:
# 6eUKZXaKkcviH0Ku9w2n3V

# %%
tracks = sp.artist_top_tracks(artist_id)

# %%
tracks['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
data_tracks = []
data_albums = []
for track in tracks['tracks']:
    track_id = track['id']
    album_id = track['album']['id']
    track_name = track['name']
    album_name = track['album']['name']
    release_date = track['album']['release_date']
    duration_ms = track['duration_ms']
    explicit = track['explicit']
    popularity = track['popularity']
    spotify_url = track['external_urls']['spotify']
    num_of_tracks = track['album']['total_tracks']
    album_url = track['album']['external_urls']['spotify']
    data_tracks.append({
        'track_id': track_id,
        'track_name': track_name,
        'album_name': album_name,
        'duration_ms': duration_ms,
        'explicit': explicit,
        'popularity': popularity,
        'spotify_url': spotify_url
    })

    data_albums.append({
        'album_id': album_id,
        'album_name': album_name,
        'release_date': release_date,
        'num_of_tracks': num_of_tracks,
        'album_url': album_url
    })

# %%
import pandas as pd


df_tracks = pd.DataFrame(data_artists)
df_albums = pd.DataFrame(data_albums)

# %%
df_tracks
# Out:
#                  track_id                                         track_name  \
# 0  51ZQ1vr10ffzbwIjDCwqm4           we can't be friends (wait for your love)
# 1  1edcyazKIdKrIuz9cWpXU6                                      twilight zone
# 2  3fxDcaiomBMomHdMeCSsZ2                                          dandelion
# 3  7xoUc6faLbCqZO6fQEYprd                                      One Last Time
# 4  63y6xWR4gXz7bnUGOk8iI6                                           Into You
# 5  1oFAF1hdPOickyHgbuRjyX  Save Your Tears (Remix) (with Ariana Grande) -...
# 6  0Lmbke3KNVFXtoH2mMSHCw                                    the boy is mine
# 7  2o1pb13quMReXZqE7jWsgq                           intro (end of the world)
# 8  3bdSZEgKApb7vGxDxyrpdO                                               warm
# 9  0T3gCq5ZQvGq9jqZmaAff1                                          Hampstead
#
#                                           album_name  duration_ms  explicit  \
# ...

# %%
df_albums
# Out:
#                  album_id               album_name release_date  \
# 0  3T4tUhGYeRNVUGevb0wThu               ÷ (Deluxe)   2017-03-03
# 1  3T4tUhGYeRNVUGevb0wThu               ÷ (Deluxe)   2017-03-03
# 2  6NoBzYmh5gUusGPCfg0pct      x (Wembley Edition)         2013
# 3  6NoBzYmh5gUusGPCfg0pct      x (Wembley Edition)         2013
# 4  32iAEBstCjauDhyKpGjTuq                        =   2021-10-25
# 5  32iAEBstCjauDhyKpGjTuq                        =   2021-10-25
# 6  5xD1PSd5c5APDM0SdkkqnH  +-=÷× (Tour Collection)   2024-09-27
# 7  3T4tUhGYeRNVUGevb0wThu               ÷ (Deluxe)   2017-03-03
# 8  37HwcDtLqY2WXN7NArODvI                   Azizam   2025-04-04
# 9  3T4tUhGYeRNVUGevb0wThu               ÷ (Deluxe)   2017-03-03
#
#    num_of_tracks                                          album_url
# 0             16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 1             16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# ...

# %%
df_albums.drop_duplicates(subset=['album_id'], inplace=True)

# %%
df_albums
# Out:
#                  album_id               album_name release_date  \
# 0  3T4tUhGYeRNVUGevb0wThu               ÷ (Deluxe)   2017-03-03
# 2  6NoBzYmh5gUusGPCfg0pct      x (Wembley Edition)         2013
# 4  32iAEBstCjauDhyKpGjTuq                        =   2021-10-25
# 6  5xD1PSd5c5APDM0SdkkqnH  +-=÷× (Tour Collection)   2024-09-27
# 8  37HwcDtLqY2WXN7NArODvI                   Azizam   2025-04-04
#
#    num_of_tracks                                          album_url
# 0             16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2             24  https://open.spotify.com/album/6NoBzYmh5gUusGP...
# 4             14  https://open.spotify.com/album/32iAEBstCjauDhy...
# 6             24  https://open.spotify.com/album/5xD1PSd5c5APDM0...
# 8              1  https://open.spotify.com/album/37HwcDtLqY2WXN7...

# %%
df_albums['release_date'] = pd.to_datetime(df_albums['release_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df_albums['release_date'] = pd.to_datetime(df_albums['release_date'])
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df_albums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   album_id       6 non-null      object
#  1   album_name     6 non-null      object
#  2   release_date   6 non-null      datetime64[ns]
#  3   num_of_tracks  6 non-null      int64
#  4   album_url      6 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df_albums['release_month'] = df_albums['release_date'].dt.month
df_albums['release_year'] = df_albums['release_date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df_albums['release_month'] = df_albums['release_date'].dt.month
#       2 df_albums['release_year'] = df_albums['release_date'].dt.year
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df_albums.drop(columns=['release_date'], inplace=True)

# %%
df_albums
# Out:
#                  album_id                                         album_name  \
# 0  5EYKrEDnKhhcNxGedaRQeK                                   eternal sunshine
# 1  2xqTa2dCR54yYHEcttiXyD  eternal sunshine deluxe: brighter days ahead (...
# 3  6EVYTRG1drKdO8OnIQBeEj                             My Everything (Deluxe)
# 4  3pdKKSqqLVIKmRTGw0x2N7                                    Dangerous Woman
# 5  4ZyeHIgdujClXSjC2cSqSb                               After Hours (Deluxe)
# 9  7saicsozAZSsKEVQh4WAig  eternal sunshine deluxe: brighter days ahead (...
#
#    num_of_tracks                                          album_url  \
# 0             13  https://open.spotify.com/album/5EYKrEDnKhhcNxG...
# 1             38  https://open.spotify.com/album/2xqTa2dCR54yYHE...
# 3             15  https://open.spotify.com/album/6EVYTRG1drKdO8O...
# 4             11  https://open.spotify.com/album/3pdKKSqqLVIKmRT...
# 5             18  https://open.spotify.com/album/4ZyeHIgdujClXSj...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
